# %%
# !pip3 install opensimplex
# Out:
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# ...
#   Using cached opensimplex-0.3-py3-none-any.whl (15 kB)
# ...
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# ...
# WARNING: You are using pip version 21.2.4; however, version 21.3 is available.
# You should consider upgrading via the '/opt/homebrew/opt/python@3.9/bin/python3.9 -m pip install --upgrade pip' command.

# %%
# !pip3 install matplotlib
# Out:
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# ...
#      |████████████████████████████████| 37.9 MB 13.3 MB/s eta 0:00:01
# ...
#   Using cached cycler-0.10.0-py2.py3-none-any.whl (6.5 kB)
# ...
#      |████████████████████████████████| 59 kB 7.3 MB/s eta 0:00:011
# ...
#   Using cached numpy-1.21.2-cp39-cp39-macosx_11_0_arm64.whl (12.4 MB)
# ...
#      |████████████████████████████████| 2.8 MB 15.4 MB/s eta 0:00:01
# ...
#   Using cached pyparsing-2.4.7-py2.py3-none-any.whl (67 kB)
# ...
#   Using cached python_dateutil-2.8.2-py2.py3-none-any.whl (247 kB)
# ...
#   Using cached six-1.16.0-py2.py3-none-any.whl (11 kB)
# ...
#   ERROR: Command errored out with exit status 1:
# ...

# %%
import numpy as np
from opensimplex import OpenSimplex
from matplotlib import pyplot as plt
import math

# %%
tmp = OpenSimplex()
print(tmp.noise2d(x=10,y=10))
# Out:
# 0.7320515695722086

# %%
for i in range(100):
    print(tmp.noise2d(x=i,y=10))
# Out:
# -0.3667265095964798
# 0.8051325753176226
# -0.13173485754606556
# 0.044714270611474045
# 0.07182412791490458
# 0.12972511303582127
# -0.037142290904728176
# -0.7016348736570058
# 0.16309683137839828
# -0.02674609971381859
# 0.7320515695722086
# -0.058904124672157165
# 0.22914766621061972
# -0.405459757989748
# 0.11801152349542646
# -0.41216467517868816
# 0.23594222189139188
# -0.15631225583472402
# 0.31481946578884845
# -0.17922086986718647
# 0.6526380046359989
# -0.6777894631084168
# 0.20007561532608897
# -0.0459659291390694
# 0.4548762371649197
# -0.14329237360634256
# 0.10134020284529065
# -0.594066904003423
# -0.12404186257466498
# 0.003555575354941792
# 0.7960666283421226
# -0.0999988155436975
# 0.42444759063584564
# 0.33280140625284654
# -0.3555396868926019
# -0.3377017050734071
# 0.24061709879113174
# -0.2633918279573955
# 0.45908307443298785
# -0.4359584548135641
# 0.35897894688321563
# 0.48754288784238875
# 0.019615538225374745
# -0.5689080263175414
# 0.6621772153786023
# ...

# %%
user_input = [    
    [
        [ 0, 480, 65 ],
        [ 1020, 1440, 65 ]
    ],

    [
        [ 0, 480, 65 ],
        [ 1020, 1440, 65 ]
    ],

    [
        [ 0, 480, 65 ],
        [ 1020, 1440, 65 ]
    ],
    
    [
        [ 0, 480, 65 ],
        [ 1020, 1440, 65 ]
    ],

    [
        [ 0, 480, 65 ],
        [ 1020, 1440, 65 ]
    ],

    [
        [ 0, 1440, 65 ],
    ],

    [
        [ 0, 1440, 65 ],
    ],

]

# %%
blocks = []
for day in user_input:
    for block in day:
        blocks.append(block)

# %%
blocks
# Out:
# [[0, 480, 65],
#  [1020, 1440, 65],
#  [0, 480, 65],
#  [1020, 1440, 65],
#  [0, 480, 65],
#  [1020, 1440, 65],
#  [0, 480, 65],
#  [1020, 1440, 65],
#  [0, 480, 65],
#  [1020, 1440, 65],
#  [0, 1440, 65],
#  [0, 1440, 65]]

# %%
year_data = []
for block in blocks:
    year = [block]*52
    year_data.append(year)

# %%
year_data
# Out:
# [[[0, 480, 65],
#   [0, 480, 65],
#   [0, 480, 65],
#   [0, 480, 65],
#   [0, 480, 65],
#   [0, 480, 65],
#   [0, 480, 65],
#   [0, 480, 65],
#   [0, 480, 65],
#   [0, 480, 65],
#   [0, 480, 65],
#   [0, 480, 65],
#   [0, 480, 65],
#   [0, 480, 65],
#   [0, 480, 65],
#   [0, 480, 65],
#   [0, 480, 65],
#   [0, 480, 65],
#   [0, 480, 65],
#   [0, 480, 65],
#   [0, 480, 65],
#   [0, 480, 65],
#   [0, 480, 65],
#   [0, 480, 65],
#   [0, 480, 65],
#   [0, 480, 65],
#   [0, 480, 65],
#   [0, 480, 65],
#   [0, 480, 65],
#   [0, 480, 65],
#   [0, 480, 65],
#   [0, 480, 65],
#   [0, 480, 65],
#   [0, 480, 65],
#   [0, 480, 65],
#   [0, 480, 65],
#   [0, 480, 65],
#   [0, 480, 65],
#   [0, 480, 65],
#   [0, 480, 65],
#   [0, 480, 65],
#   [0, 480, 65],
#   [0, 480, 65],
#   [0, 480, 65],
#   [0, 480, 65],
#   [0, 480, 65],
#   [0, 480, 65],
#   [0, 480, 65],
#   [0, 480, 65],
#   [0, 480, 65],
#   [0, 480, 65],
#   [0, 480, 65]],
#  [[1020, 1440, 65],
#   [1020, 1440, 65],
# ...

# %%
year_data[11][51][1]
# Out:
# 1440

# %%
import random
def noise(x):
    x *= 0.1
    v = 0.3*(-3.2*math.sin(-1.3*x)-1.2*math.sin(-1.7*math.e*x)+1.9*math.sin(0.7*math.pi*x) + random.randint(-100,100)/100) 
    return v

# %%
def datagen(year_data):
#     year_data = og_data.copy()
    #count = 0
#     for i in range(len(year_data)):
#         for j in range(len(year_data[i])):
#             #count += 1
#             #print(count)
#             x = j+i
#             year_data[i][j][0] += 5*noise(x)
#             print(year_data[i][j][0])
#             year_data[i][j][1] += 5*noise(0.5*x)
#             print(year_data[i][j][1])
#             year_data[i][j][2] += noise(0.7*x)
#             print(year_data[i][j][2])
#             print("-")
#             for k in range(j+1):
#                 print(year_data[i][k])
#             print("------------")
#         print(year_data[i])
#         print("*******************")
#     print(year_data)
#     return year_data
    ia = []
    for i in range(len(year_data)):
        ja = []
        for j in range(len(year_data[i])):
            ka = []
#             print(year_data[i][j])
            for k in range(len(year_data[i][j][:2])):
                
                n = noise(j)
                nv = round(year_data[i][j][k] + 2*n)
                ka.append(nv)
            ka.append(year_data[i][j][2])
            ja.append(ka)
        ia.append(ja)
                
    return ia

year_data = datagen(year_data)

# %%
plt.plot(year_data[0])

# %%
year_data = datagen(year_data)

# %%
def get_both(block):
    #print(block)
    start_n = 0
    end_n = 0
    d = 0
    for i,v in enumerate(block):
        w = i**8
        start_n += w*v[0]
        end_n += w*v[1]
        d += w
    n = len(block)
    start = start_n/d
    end = end_n/d
    return (start,end)

# %%
def get_both3(block):
    
    start = start_n/(n*(n-1)/2)
    end = end_n/(n*(n-1)/2)
    return (start,end)

# %%
def ema(s, n):
    """
    returns an n period exponential moving average for
    the time series s

    s is a list ordered from oldest (index 0) to most
    recent (index -1)
    n is an integer

    returns a numeric array of the exponential
    moving average
    """
    #s = array(s)
    ema = []
    j = 1

    #get n sma first and calculate the next n period ema
    sma = sum(s[:n]) / n
    multiplier = 2 / float(1 + n)
    ema.append(sma)

    #EMA(current) = ( (Price(current) - EMA(prev) ) x Multiplier) + EMA(prev)
    ema.append(( (s[n] - sma) * multiplier) + sma)

    #now calculate the rest of the values
    for i in s[n+1:]:
        tmp = ( (i - ema[j]) * multiplier) + ema[j]
        j = j + 1
        ema.append(tmp)

    return ema

# %%
ema([1,2,3,4,5,6],5)
# Out:
# [3.0, 4.0]

# %%
get_both(year_data[0])
# Out:
# (-2.3997593971787814, 477.55036496145516)

# %%
block = year_data[0]

generated_data = []

for i in range(2,len(block)+2):
    trunc = block[:i+1]
    #print(trunc)   
    a,b = get_both(trunc)
    generated_data.append([a,b])

plt.plot([x[1] for x in generated_data], label="Predicted")
plt.plot([x[1] for x in year_data[0]], label = "Actual")
plt.legend()

plt.title('Predicted vs. Actual Leave Times for Block 0')
plt.xlabel('Week')
plt.ylabel('User Leave Time')

plt.show()

# %%
n = len(generated_data)
rmse = np.linalg.norm(np.asarray([x[1] for x in generated_data]) - np.asarray([x[1] for x in year_data[0]])) / np.sqrt(n)
rmse
# Out:
# 0.9012116383318373
